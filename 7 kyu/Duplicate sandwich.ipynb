# %%
Task
In this kata you will be given a list consisting of unique elements except for one thing that appears twice.

Your task is to output a list of everything inbetween both occurrences of this element in the list.

Examples:
[0, 1, 2, 3, 4, 5, 6, 1, 7, 8] => [2, 3, 4, 5, 6]
['None', 'Hello', 'Example', 'hello', 'None', 'Extra'] => ['Hello', 'Example', 'hello']
[0, 0] => []
[True, False, True] => [False]
['e', 'x', 'a', 'm', 'p', 'l', 'e'] => ['x', 'a', 'm', 'p', 'l']
Notes
All elements will be the same datatype.
All used elements will be hashable.


import collections
def duplicate_sandwich(arr):
    print(arr)
    a=[item for item, count in collections.Counter(arr).items() if count > 1][0]
    print(a)
    if len(arr)==3 and arr[0]==arr[2]:return [arr[1]]
    print(arr.index(a,arr.index(a)+1))
    return(arr[arr.index(a)+1:arr.index(a,arr.index(a)+1)])




def duplicate_sandwich(arr):
    start, end = [i for i, x in enumerate(arr) if arr.count(x) > 1]
    return arr[start+1:end]
    

    
    
def duplicate_sandwich(arr):
    pos = {}
    for i, x in enumerate(arr):
        if x in pos:
            return arr[pos[x] + 1 : i]
        pos[x] = i

        
        
def duplicate_sandwich(lst):
    i1, i2 = (i for i, item in enumerate(lst) if lst.count(item) > 1)
    return lst[i1+1:i2]
